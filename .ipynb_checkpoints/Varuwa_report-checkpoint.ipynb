# %% [markdown]
# # EEGManyPipelines - Team Varuwa Analysis

# %% [markdown]
# ## Question 1: N1 for scene type
# - Only select 600 new images (1st presentations), without invalid
# - Baseline correct
# - compute grand average (all subjects, both conditions)
# - Find N1 in grand average => focus on this time window, perform mass univariate cluster statistics in space (find significant eletrode clusters where mean voltage in time window of analysis is different between scene categories) => maybe peform TFCE (for carving out the cluster borders).

# %% [markdown]
# ## Question 2: novelty
# - exclude invalid, keep incorrects
# - compare first vs. third presentation of same images (third presentation: subsequent memory is "missing")
# - average over frontal central channels (5-6, Fz to Cz)
# - average over poseterior channels: everything posterior inluding CPs (except P9, P10, Iz)average over average over time window of interest
# - For frequency: use envelope of bp-filtered signal
#     - simple within-subject t-test (old new))

# %% [markdown]
# ## Question 3: recognition effect
# - include trials from second and third repetition!
# - Analyze up to 1 second.
# - Perform temporo-spatial-(spectral) cluster permutation stat.

# %% [markdown]
# ## Question 4: same as 3.
# - include only first presentation [*030, *040] vs. [*031, *041]
# - exclude invalid trials
